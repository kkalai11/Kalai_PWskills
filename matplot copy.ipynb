# %%
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 3.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 4.5 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 4.9 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 5.3 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 4.7 MB/s eta 0:00:00
# ...

# %%
# Out:
# C:\Users\murum\AppData\Local\Temp\ipykernel_22412\1943913654.py:13: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=["Box 1", "Box 2"])
